# %%
import pandas as pd

# %%
df = pd.read_excel('test.xlsx')
df.head(5)
# Out:
#                 Ticker           A          B          C          D       E  \
# 0                 Date         NaN        NaN        NaN        NaN     NaN
# 1  2024-01-01 00:00:00  148.000000  215.00000  457.00000  356.00000  325.00
# 2  2024-01-02 00:00:00  156.880000  223.60000  470.71000  348.88000  325.00
# 3  2024-01-03 00:00:00  153.742400  237.01600  498.95260  366.32400  325.00
# 4  2024-01-04 00:00:00  147.592704  229.90552  474.00497  380.97696  308.75
#
#           F         G        H          I          J          K           L  \
# 0       NaN       NaN      NaN        NaN        NaN        NaN         NaN
# 1  236.0000  450.0000  445.000  347.00000  476.00000  458.00000  211.000000
# 2  243.0800  432.0000  427.200  367.82000  490.28000  444.26000  223.660000
# 3  247.9416  444.9600  427.200  389.88920  514.79400  430.93220  225.896600
# 4  247.9416  440.5104  435.744  370.39474  519.94194  452.47881  228.155566
#
#            M         N          O           P
# ...

# %%
df.stack
# Out:
# <bound method DataFrame.stack of                  Ticker           A           B           C           D  \
# 0                  Date         NaN         NaN         NaN         NaN
# 1   2024-01-01 00:00:00  148.000000  215.000000  457.000000  356.000000
# 2   2024-01-02 00:00:00  156.880000  223.600000  470.710000  348.880000
# 3   2024-01-03 00:00:00  153.742400  237.016000  498.952600  366.324000
# 4   2024-01-04 00:00:00  147.592704  229.905520  474.004970  380.976960
# 5   2024-01-05 00:00:00  141.688996  239.101741  464.524871  403.835578
# 6   2024-01-06 00:00:00  145.939666  236.710723  492.396363  419.989001
# 7   2024-01-07 00:00:00  150.317856  243.812045  502.244290  428.388781
# 8   2024-01-08 00:00:00  148.814677  236.497684  502.244290  441.240444
# 9   2024-01-09 00:00:00  145.838384  248.322568  522.334062  423.590826
# 10  2024-01-10 00:00:00  147.296767  263.221922  496.217359  402.411285
# 11  2024-01-11 00:00:00  150.242703  273.750799  506.141706  422.531849
# ...
